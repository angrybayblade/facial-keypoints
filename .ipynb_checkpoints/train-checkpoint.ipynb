# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras 
from tensorflow.keras import Model,optimizers,losses
from tensorflow.keras.layers import *

# %matplotlib inline

# %%
X = np.load( "face_landmarks_cleaned/x_train.npy" ).reshape(-1,96,96) 
Y = np.load( "face_landmarks_cleaned/y_train.npy" ).astype(np.uint16)
x = np.load( "face_landmarks_cleaned/x_test.npy" ).reshape(-1,96,96) 
y = np.load( "face_landmarks_cleaned/y_test.npy" ).astype(np.uint16)

# %%
# y_train = np.reshape( y_train , ( -1 , 1 , 1 , 30 ))
# y_test = np.reshape( y_test , ( -1 , 1 , 1 , 30 ))

# %%
for i in range(len(X)):X[i] = X[i].T
for i in range(len(x)):x[i] = x[i].T

# %%
Y[0]
# Out:
# array([67, 36, 29, 34, 60, 37, 75, 37, 36, 36, 22, 36, 59, 28, 80, 31, 39,
#        28, 16, 29, 48, 51, 62, 73, 29, 72, 47, 66, 46, 81], dtype=uint16)

# %%
plt.figure(figsize=(8,8))
plt.imshow(X[0],cmap='gray')
plt.scatter(Y[0,::2],Y[0,1::2])

# %%
def conv(x,filters,kernel_size=1,strides=1,use_bias=True):
    x = Conv2D(filters,kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    return x

def conv_bt(x,filters,kernel_size=1,strides=1,use_bias=True):
    x = Conv2D(filters,kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    x = BatchNormalization()(x)
    return x

def conv(x,filters,kernel_size=1,strides=1,use_bias=True,activation='swish'):
    x = Conv2D(filters,kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    return x

def dwconv(x,filters,kernel_size=3,strides=1,use_bias=True):
    x = DepthwiseConv2D(kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    return x

def dwconv_bt(x,filters,kernel_size=3,strides=1,use_bias=True):
    x = DepthwiseConv2D(kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    x = BatchNormalization()(x)
    return x

def dwconv(x,filters,kernel_size=3,strides=1,use_bias=True,activation='swish'):
    x = DepthwiseConv2D(kernel_size=kernel_size,strides=strides,use_bias=use_bias)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    return x

def block(x):
    x = dw

im_in = Input(shape=(96,96,1))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 17227776/17225924 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-28233189adff> in <module>
#       1 im_in = Input(shape=(96,96,1))
# ----> 2 net = keras.applications.MobileNet(include_top=False,input_tensor=im_in,weights='imagenet')
#       3
#       4 model = Model(im_in,net.output)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/mobilenet.py in MobileNet(input_shape, alpha, depth_multiplier, dropout, include_top, weights, input_tensor, pooling, classes, classifier_activation, **kwargs)
#     306       weights_path = data_utils.get_file(
#     307           model_name, weight_path, cache_subdir='models')
# ...

# %% [markdown]
# model.su
